# %% [markdown]
# Q1) Explain why we have to use the Exception class while creating a Custom Exception.

# %% [markdown]
# Exceptions are caught and handled using the try-except construct. By using the Exception class as the base class for your custom exception, we ensure that it will be caught by except blocks that catch general exceptions. This allows us to handle your custom exception along with other built-in exceptions or even catch all exceptions if necessary.

# %% [markdown]
# Q2) Write a python program to print Python Exception Hierarchy.

# %%
def print_exception_hierarchy(exception_class, indent=0):
    print(' ' * indent + exception_class.__name__)
    for subclass in exception_class.__subclasses__():
        print_exception_hierarchy(subclass, indent + 4)

print_exception_hierarchy(BaseException)
# Out:
# BaseException
#     Exception
#         TypeError
#             FloatOperation
#             MultipartConversionError
#         StopAsyncIteration
#         StopIteration
#         ImportError
#             ModuleNotFoundError
#             ZipImportError
#         OSError
#             ConnectionError
#                 BrokenPipeError
#                 ConnectionAbortedError
#                 ConnectionRefusedError
#                 ConnectionResetError
#                     RemoteDisconnected
#             BlockingIOError
#             ChildProcessError
#             FileExistsError
#             FileNotFoundError
#             IsADirectoryError
#             NotADirectoryError
#             InterruptedError
#                 InterruptedSystemCall
#             PermissionError
#             ProcessLookupError
#             TimeoutError
#             UnsupportedOperation
#             itimer_error
#             herror
#             gaierror
#             SSLError
# ...

# %% [markdown]
# Q3) What errors are defined in the ArithmeticError class? Explain any two with an example.

# %%
print_exception_hierarchy(ArithmeticError)
# Out:
# ArithmeticError
#     FloatingPointError
#     OverflowError
#     ZeroDivisionError
#         DivisionByZero
#         DivisionUndefined
#     DecimalException
#         Clamped
#         Rounded
#             Underflow
#             Overflow
#         Inexact
#             Underflow
#             Overflow
#         Subnormal
#             Underflow
#         DivisionByZero
#         FloatOperation
#         InvalidOperation
#             ConversionSyntax
#             DivisionImpossible
#             DivisionUndefined
#             InvalidContext

# %%
# ZeroDivisionError
x=10/0
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[9], line 2
#       1 # ZeroDivisionError
# ----> 2 x=10/0
#
# ZeroDivisionError: division by zero

# %%
# OverflowError
import math
print(math.exp(1000))
# Out:
# ---------------------------------------------------------------------------
# OverflowError                             Traceback (most recent call last)
# Cell In[12], line 3
#       1 # OverflowError
#       2 import math
# ----> 3 print(math.exp(1000))
#
# OverflowError: math range error

# %% [markdown]
# Q4) Why LookupError class is used? Explain with an example KeyError and IndexError.

# %% [markdown]
# LookupError class is a base class for exceptions related to lookup operations. It serves as a parent class for exceptions that occur when a lookup or indexing operation fails or encounters an error.

# %% [markdown]
# IndexError: This exception is raised when you try to access an index or sequence element that is out of range.

# %%
l=[1,2,3]
l[3]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[13], line 2
#       1 l=[1,2,3]
# ----> 2 l[3]
#
# IndexError: list index out of range

# %% [markdown]
# KeyError: This exception is raised when you try to access a dictionary using a key that does not exist.

# %%
d={'name':'Tarun','age':23}
d['address']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[14], line 2
#       1 d={'name':'Tarun','age':23}
# ----> 2 d['address']
#
# KeyError: 'address'

# %% [markdown]
# Q5) Explain ImportError. What is ModuleNotFoundError?

# %% [markdown]
# ImportError is raised when a module, or member of a module, cannot be imported.
# ModuleNotFoundError occurs when you're trying to access or use a module that cannot be found or is not accessible in the current Python environment.

# %% [markdown]
# Q6) List down some best practices for exception handling in python.

# %% [markdown]
# Specific Exception Handling, Use Multiple Except Clauses, Avoid Bare Except, Clean-Up with Finally, Logging and Error Messages
