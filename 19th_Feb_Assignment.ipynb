# %% [markdown]
# Q1) What is Flask Framework? What are the advantages of Flask Framework?

# %% [markdown]
# Flask is a popular web framework written in Python. It is designed to be lightweight, flexible, and easy to use, making it a popular choice for building web applications and APIs.
#
# Advantages:
# Lightweight and minimalist, Easy to get started, Flexibility, Python integration

# %% [markdown]
# Q2) Create a simple Flask application to display ‘Hello World!!’. Attach the screenshot of the output in
# Jupyter Notebook.

# %% [markdown]
# ![Screenshot 2023-05-28 165554.png](attachment:4d1cd47f-2363-48ed-b8d9-787865da8e9c.png)

# %% [markdown]
# Q3) What is App routing in Flask? Why do we use app routes?

# %% [markdown]
# app routing refers to the process of mapping URLs (Uniform Resource Locators) to specific functions. we use app routes to bind a URL pattern to a function

# %% [markdown]
# Q4) Create a “/welcome” route to display the welcome message “Welcome to ABC Corporation” and a “/”
# route to show the following details:
# Company Name: ABC Corporation
# Location: India
# Contact Detail: 999-999-9999

# %% [markdown]
# route: "/" ![Screenshot 2023-05-28 170944.png](attachment:213e65fb-320b-45e6-bf8a-ae252e02b9a2.png)
#
# route : "/welcome" ![Screenshot 2023-05-28 171008.png](attachment:27f58eb9-c650-4ab7-9afb-e1236aba7a90.png)

# %% [markdown]
# Q5) What function is used in Flask for URL Building? Write a Python code to demonstrate the working of the
# url_for() function.

# %% [raw]
# # url_for() is used in Flask for URL Building.
#
# @app.route('/admin')
# def hello_admin():
#    return 'Hello Admin'
#
# @app.route('/guest/<guest>')
# def hello_guest(guest):
#    return 'Hello %s as Guest' % guest
#
# @app.route('/user/<name>')
# def hello_user(name):
#    if name =='admin':
#       return redirect(url_for('hello_admin'))
#    else:
#       return redirect(url_for('hello_guest',guest = name))
